# %% [markdown]
# # 12_04.날짜 검색 추가(BeautifulSoup)

# %% [markdown]
# ## 1.기본 package 설정

# %%
## 1.기본
import numpy as np  # numpy 패키지 가져오기
import pandas as pd # pandas 패키지 가져오기
import matplotlib.pyplot as plt # 시각화 패키지 가져오기

## 2.크롤링
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

# %%
# 네이버에서 접속 제한 풀기
# req = requests.get(news_url, headers={'User-agent': 'Mozilla/5.0'})
# soup = BeautifulSoup(req.text, "lxml")  # html에 대하여 접근할 수 있도록

# %%
# 네이버에서 접속 제한 풀기
# User-Agent 확인: https://www.useragentstring.com/
header = ({"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
          "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"})

# %% [markdown]
# ## 2.검색어 설정

# %%
search_addr = (f"https://search.naver.com/search.naver?where=news"
                "&sm=tab_pge&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sort=1&photo=3"
                "&field=0&pd=1&ds=2023.07.24&de=2023.07.31&mynews=0"
                "&office_type=0&office_section_code=0&news_office_checked="
                "&nso=so:dd,p:1w,a:all&start=")

# %% [markdown]
# ## 3.URL주소 검색

# %%
start, last, step = 1, 50, 10
news_url = []

for i in range(start, last, step):
    import requests   # 접속할때 마다 실행해야 함
    search_url = search_addr + str(i)
    print(search_url)
    requests = requests.get(search_url, headers = header)
    bs = BeautifulSoup(requests.text)
    url = bs.select("div > div > div.news_info > div.info_group > a:nth-child(4)")

    for url in tqdm(url):
        news_url.append(url["href"])

news_url
# Out:
# https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sort=1&photo=3&field=0&pd=1&ds=2023.07.24&de=2023.07.31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:1w,a:all&start=1
# 100%|██████████| 10/10 [00:00<00:00, 3975.64it/s]
# https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sort=1&photo=3&field=0&pd=1&ds=2023.07.24&de=2023.07.31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:1w,a:all&start=11
# 100%|██████████| 10/10 [00:00<00:00, 16238.11it/s]
# https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sort=1&photo=3&field=0&pd=1&ds=2023.07.24&de=2023.07.31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:1w,a:all&start=21
# 100%|██████████| 10/10 [00:00<00:00, 14619.39it/s]
# https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sort=1&photo=3&field=0&pd=1&ds=2023.07.24&de=2023.07.31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:1w,a:all&start=31
# 100%|██████████| 10/10 [00:00<00:00, 67001.66it/s]
# https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sort=1&photo=3&field=0&pd=1&ds=2023.07.24&de=2023.07.31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:1w,a:all&start=41
# 100%|██████████| 10/10 [00:00<00:00, 70138.86it/s]
# ['https://n.news.naver.com/mnews/article/654/0000048105?sid=102',
#  'https://n.news.naver.com/mnews/article/087/0000986793?sid=102',
#  'https://n.news.naver.com/mnews/article/015/0004875497?sid=105',
#  'https://n.news.naver.com/mnews/article/015/0004875451?sid=101',
#  'https://n.news.naver.com/mnews/article/029/0002817326?sid=101',
#  'https://n.news.naver.com/mnews/article/015/0004875413?sid=101',
#  'https://n.news.naver.com/mnews/article/009/0005167465?sid=101',
#  'https://n.news.naver.com/mnews/article/029/0002817290?sid=105',
#  'https://n.news.naver.com/mnews/article/030/0003122355?sid=101',
#  'https://n.news.naver.com/mnews/article/030/0003122331?sid=101',
#  'https://n.news.naver.com/mnews/article/088/0000828464?sid=101',
#  'https://n.news.naver.com/mnews/article/008/0004920255?sid=102',
#  'https://n.news.naver.com/mnews/article/666/0000017805?sid=102',
#  'https://n.news.naver.com/mnews/article/008/0004920212?sid=101',
#  'https://n.news.naver.com/mnews/article/016/0002178061?sid=101',
#  'https://n.news.naver.com/mnews/article/277/0005294920?sid=101',
#  'https://n.news.naver.com/mnews/article/030/0003122243?sid=102',
#  'https://n.news.naver.com/mnews/article/016/0002178000?sid=101',
#  'https://n.news.naver.com/mnews/article/030/0003122229?sid=105',
#  'https://n.news.naver.com/mnews/article/030/0003122228?sid=105',
#  'https://n.news.naver.com/mnews/article/030/0003122212?sid=105',
#  'https://n.news.naver.com/mnews/article/018/0005542566?sid=101',
#  'https://n.news.naver.com/mnews/article/018/0005542340?sid=101',
#  'https://n.news.naver.com/mnews/article/081/0003381788?sid=102',
#  'https://n.news.naver.com/mnews/article/005/0001627873?sid=101',
#  'https://n.news.naver.com/mnews/article/005/0001627860?sid=110',
#  'https://n.news.naver.com/mnews/article/658/0000048266?sid=110',
#  'https://n.news.naver.com/mnews/article/008/0004919941?sid=110',
#  'https://n.news.naver.com/mnews/article/654/0000047981?sid=101',
#  'https://n.news.naver.com/mnews/article/469/0000752940?sid=110',
#  'https://n.news.naver.com/mnews/article/032/0003240019?sid=102',
#  'https://n.news.naver.com/mnews/article/656/0000058761?sid=102',
#  'https://n.news.naver.com/mnews/article/014/0005050916?sid=101',
#  'https://n.news.naver.com/mnews/article/014/0005050890?sid=102',
#  'https://n.news.naver.com/mnews/article/011/0004221370?sid=101',
#  'https://n.news.naver.com/mnews/article/015/0004874950?sid=101',
#  'https://n.news.naver.com/mnews/article/030/0003122119?sid=105',
#  'https://n.news.naver.com/mnews/article/658/0000048203?sid=100',
#  'https://n.news.naver.com/mnews/article/087/0000986490?sid=102',
#  'https://n.news.naver.com/mnews/article/030/0003122095?sid=101',
#  'https://n.news.naver.com/mnews/article/029/0002817034?sid=105',
#  'https://n.news.naver.com/mnews/article/087/0000986444?sid=102',
#  'https://n.news.naver.com/mnews/article/030/0003122079?sid=105',
#  'https://n.news.naver.com/mnews/article/029/0002817004?sid=105',
#  'https://n.news.naver.com/mnews/article/018/0005541996?sid=105',
#  'https://sports.news.naver.com/news.nhn?oid=021&aid=0002585960',
#  'https://n.news.naver.com/mnews/article/016/0002177517?sid=105',
#  'https://n.news.naver.com/mnews/article/277/0005294242?sid=101',
#  'https://n.news.naver.com/mnews/article/277/0005294229?sid=101',
#  'https://n.news.naver.com/mnews/article/277/0005294110?sid=100']

# %% [markdown]
# ## 4.뉴스 저장

# %%
news_no = []
news_title = []
news_body = []
news_press = []

for i, url in tqdm(enumerate(news_url)):
    import requests                                       # 접속할때 마다 실행해야 함
    requests = requests.get(url, headers = header)            # 개별 페이지 header
    news_html = BeautifulSoup(requests.text,"html.parser")
    news_html

    # 글번호
    no = i + 1
    news_no.append(no)

    # 제목
    title = news_html.select_one("#title_area > span").text
    news_title.append(title)

    # 본문
    body = news_html.select_one("#dic_area").text
    news_body.append(body)

    # 신문사
    press = news_html.select_one("img.media_end_head_top_logo_img.light_type")["title"]
    news_press.append(press)
# Out:
# 50it [00:28,  1.73it/s]

# %% [markdown]
# ## 5.테이블로 저장

# %%
news_df = pd.DataFrame({'번호': news_no, '제목':news_title,'본문':news_body,'출판사':news_press})
news_df
# Out:
#     번호                                                 제목  \
# 0    1  박상우 엔케이맥스 대표 "건기식·세포치료제 사업으로 美·中 시장 동시 공략" [코스...
# 1    2     [THE INFLUENCER] 승무원이 하는 롤플레잉… 궁금증에 저절로 구독 `꾹`
# 2    3  [THE INFLUENCER] 현대인 만성질환 거북목 교정… 유튜브 보며 집에서 `...
# 3    4                                   주니어 생글생글 여름 경제캠프
# 4    5               "빨리 달라" 5배 비싸도 주문 폭발…삼성·SK 발 빠르게 나선다
# 5    6                     인도로 몰려가는 美 테크기업들…AMD도 "4억弗 투자"
# 6    7                [fn이사람] "리스크 미리 알리는 ‘금융기상청’ 예보 될 것"
# 7    8                           쿠팡, 스포츠 중계로 2030 충성고객 쑥쑥
# 8    9              인터넷은행-빅테크 제3 연합...케이뱅크·토스 '주담대 시장' 동맹
# 9   10                      원주세브란스기독병원 김익용 교수 보건복지부 장관 표창
# 10  11           [송민택 교수의 핀테크 4.0] 보험상품 비교·추천 서비스와 시장의 기대
# 11  12              박수용 서강대 교수 “웹 3.0 기반 디지털 혁신이 신성장 이끈다”
# 12  13              “AI칩에 클라우드 운명 달렸다” MS 우려에 삼성·SK 웃는 이유
# 13  14                 NDS, 문화재청 '국가유산 원형기록 통합 DB구축사업' 수주
# 14  15           AI 농기계·ICT 축사… ‘스마트농업’으로 FTA·고령화 복합위기 돌파
# 15  16                주택시장 공급지표 악화…2~3년 뒤 공급 가뭄, 집값 상승 우려
# 16  17                        [월요전망대] 무역수지 2개월 연속 흑자 이어질까
# 17  18          [특집] “객관적 일자리 효과, 현실 산업 기반한 미래 산업 육성이 관건”
# 18  19                              보험료에 대출·연체이력 반영 길 열린다
# 19  20                MS “AI 반도체 부족, 클라우드 서비스 중단 위험” 첫 경고
# 20  21            박정과 천재교과서 대표 "AI 교과서로 전환은 교육혁신 모멘텀 될 것"
# 21  22                   서초·개포 1만가구 들어선다…"강남 전세, 하반기 노려라"
# 22  23                        "클라우드 중단될수도" MS 'AI칩 부족' 경고
# 23  24                          "AI로 가상 환자군 만들고 임상 병원 선정"
# 24  25                         美 고용·소비 모두 탄탄 … 연착륙에 힘 실린다
# 25  26                             "로봇·반도체…M&A 활성화 물꼬트겠다"
# 26  27                               [매경춘추] 51을 주고 49를 갖기
# 27  28                         KT CEO 이번주 최종면접 판가름…운명의 한주
# 28  29      엄청나게 거칠고, 믿을수 없게 가벼운… '삿대질' 논평 경쟁에 남는 건 '비호감'
# 29  30                      양양군, 방범 취약지역에 방범용 CCTV 82대 추가
# 30  31              경북 국민의힘 고령·성주·칠곡군 당원협의회 봉사단…수해복구 봉사활동
# 31  32               2차전지 급등락, 반도체 반등 이어질까?… 美 7월 고용지표 주목
# 32  33  서울 압축성장 노하우 나눠주고 끌어주고… “해외 수요 폭발” [심층기획-정책수출 최...
# 33  34  '여론조사 필요' 93%가 공감하지만 '선거 조사 결과 신뢰'는 40% 뿐 [여론 ...
# 34  35                    CEO 후보 3명 압축한 KT, 내달 3~4일 최종 결정
# 35  36  [전화성의 기술창업 Targeting]〈272〉초기 스타트업의 첫 번째 도전, 초기...
# 36  37                         美 PCE 2년 만에 최저…탄력받는 '골디락스'
# 37  38                    췌장암 환자 생존기간, 59세 이하에서 가장 많이 늘었다
# 38  39              '거지방' 들어가고  '무지출 챌린지'…2030이 먼저 지갑 닫았다
# 39  40                           美 '골디락스' 비결…강한 소비·투자·빅테크
# 40  41                     '민생추경'에 신재생지원금? 시급하다며 예산 키우는 野
# 41  42             계명대 동산의료원-지멘스 헬시니어스㈜ 스마트 병원 구축 위한 업무협약
# 42  43                              KT CEO 후보 김영섭·박윤영·차상균
# 43  44                  25조 KT그룹 이끌 수장은? 내부·학계·경쟁사 출신 3파전
# 44  45   수능 망해 시인 된 ‘문단의 아이돌’ “유머가 제일 중요해” 외치는 이유 [실패연대기]
# 45  46                 [알림] '2023 K-ICT 위크 인 부산' 9월 6일 개막
# 46  47           편리함 좇다 자유·정의 잃을 수도… ‘정치적 AI’에 관한 경고[북리뷰]
# 47  48            '서핑성지' 양양 "실시간 파도 컨디션·해변 혼잡도…앱이 다 알려주네"
# 48  49                         KT, 차기사장 후보 김영섭·박윤영·차상균 압축
# 49  50            "BTS나 나나 똑같다"...'언제든 콜' 폰번호 환자 주는 망막 명의
#
#                                                    본문     출판사
# 0   \n\n中 주문 이어지며 매출 본격화 기대美에 자회사 상장, 3분기에 마무리 \n\...  파이낸셜뉴스
# 1   \n\n구독자 7만3500여명 보유… 저비용 항공사 중 가장 많아승무원 브이로그·비...  디지털타임스
# 2   \n\n필라테스 강사 '자세요정', 스트레칭법 소개로 구독자 125만명재활운동 알려...  디지털타임스
# 3   \n\n9~11일 파주 웅진씽크빅 본사‘2023 주니어 생글생글 여름 경제 캠프’가...    한국경제
# 4   \n\n메모리, 판이 바뀐다(1)  '챗GPT 시대' 게임체인저AI 시대 … HBM...    한국경제
# 5   \n\n반도체 공장 지으면 70% 지원14억 인구 앞세운 노동력 강점 마이크론, 8...    한국경제
# 6   \n\n문형욱 예금보험공사 이사디지털전환으로 열린 ‘클릭런’ 시대금융사 한곳만 무너...  파이낸셜뉴스
# 7   \n\n맨시티-AT마드리드 경기 등스포츠 빅이벤트 잇달아 따내고객들 이커머스로 유인...    매일경제
# 8   \n\n\n\n\n\n출처 게티이미지뱅크인터넷은행과 빅테크가 전통금융사 텃밭으로 불...    전자신문
# 9   \n\n\n\n\n\n◇연세대 원주세브란스기독병원 김익용(사진 오른쪽) 외과학교실 ...    강원일보
# 10  \n\n\n\n\n\n송민택 동국대 겸임교수금융당국이 플랫폼 보험상품 비교·추천 서...    전자신문
# 11  \n\n\t\t\t“한국은 제조업과 반도체에서 두 번 기적을 이뤄내며 성장했습니다....    전자신문
# 12  \n\nGPU 등 AI반도체 장악 ‘호재’HBM 등 주문량 대거 급증 전망\n\n\...   헤럴드경제
# 13  \n\n\n\n\n\nNDS로고NDS(대표 김중원)는 문화재청의 '2023년~202...    전자신문
# 14  \n\n\n\n\n\n첨단디지털온실에서 토마토가 자라고 있는 모습.  농림축산식품부...    문화일보
# 15  \n\n\t\t\t침체됐던 부동산 시장이 서울 등 일부 지역을 중심으로 기지개를 켜...   아시아경제
# 16  \n\n강진규 경제부 기자\n\n\n\n산업통상자원부가 8월 1일 수출입동향을 발표...    한국경제
# 17  \n\n\n\n\n\n◇류승한 국토연구원 본부장춘천시와 강원일보사는 지난 28일 한...    강원일보
# 18  \n\nNICE가 보유한 개인 신용정보교보생명 등 보험사 판매 추진고신용자 보험료 ...    매일경제
# 19  \n\n\t\t\t\t\t\t\t\t\t\t세계 2위 클라우드 기업 마이크로소프트(...    조선일보
# 20  \n\n에듀테크에 인력 500명 투입업계 최대 'IT교육센터' 운영'밀크T'로 축적...    한국경제
# 21  \n\nCover Story하반기 대단지 '집들이' 몰려전세가 하락 전망내달 '반포...    한국경제
# 22  \n\n연례보고서에 수급 리스크 언급하드웨어 확보 비용 상승 전망\n\n\n\n/로...    서울경제
# 23  \n\n세계 1위 임상솔루션 메디데이터앤서니 코스텔로 사업부 대표"신약개발 기간·비...    한국경제
# 24  \n\n기업들 구인난 속 해고 꺼려"인력 감축" 중소기업 7%뿐"일자리 유지 땐 소...    매일경제
# 25  \n\n박용근 EY한영 대표팬데믹 위기서 호실적 이끌어내정중동 행보 속에서 연임 성...    매일경제
# 26  \n\n\n\n\n\n나는 해양학자다. 정확히는 해양생태학자다. 해양생태학은 사회학...    매일경제
# 27  \n\n\n\n\n\nKT 2023년 제1차 임시주주총회가 30일 서울 서초구 KT...    전자신문
# 28  \n\n국힘·민주 1~7월 논평 전수조사10건 가운데 9건은 비난·비아냥\n\n\n...    매일경제
# 29  \n\n\t\t\t【양양】양양군이 범죄예방을 통한 주민의 안전을 위해 올해 방범 취...    강원일보
# 30  \n\n\n\n\n\n국민의힘 고령·성주·칠곡군 당원협의회 봉사단경북 국민의힘 고령...    매일신문
# 31  \n\n[주간증시전망]\n\n\n\n지난 28일 오후 서울 중구 하나은행 명동점 딜...   머니투데이
# 32  \n\n2015년 출범한 서울국제개발협력단4월까지 35개국 83개 프로젝트 참여 사...    세계일보
# 33  \n\n\t\t\t우리는 여론조사를 신문, 방송, 인터넷, 유튜브 등을 통해 거의 ...    한국일보
# 34  \n\n정치인·대선 캠프 출신 모두 배제\t\t\t\t\t\t\t4개월째 CEO(최...    조선일보
# 35  \n\n\n\n\n\n전화성 씨엔티테크 대표이사초기창업패키지는 특정 기술이나 산업 ...    전자신문
# 36  \n\n6월 PCE 가격지수 3% 상승  고성장 속 물가안정 국면 진입탄탄한 고용이...    한국경제
# 37  \n\n전 연령선 12년 사이 4.3개월 증가일산병원 연구 유럽암학회지 게재\n\n...    경향신문
# 38  \n\n◆서울경제·신한카드 TPO소비지수 상반기 분석\n\n\n\n연합뉴스[서울경제...    서울경제
# 39  \n\n긴축 압력에도 끄덕없는 경제'금리 인상=경기 침체' 공식 깨져탄탄한 고용이 ...    한국경제
# 40  \n\n장애인 거주시설 찾은 李"취약계층 위해 추경 관철"35조 추경안 공개 당정 ...    매일경제
# 41  \n\n\n\n\n\n계명대 동산의료원과 지멘스 헬시니어스가 환자 중심 스마트 병원...    매일신문
# 42  \n\nLG그룹 출신 김영섭 재무통 평가‘KT맨’ 박윤영, 내부 지지도 강점학계 인...   헤럴드경제
# 43  \n\nLG출신 재무통 김영섭B2B 전문 'KT맨' 박윤영AI·빅데이터 권위자 차상...   아시아경제
# 44  \n\n[김지은의 ‘삶도’ 시즌2 : 실패연대기] <13>시인 오은첫 시집 낸 직후...    한국일보
# 45  \n\n\n\n\n\nK-ICT 위크 인 부산 2022지역 최대 정보통신기술(ICT...    전자신문
# 46  \n\n\n\n\n\n■ 인공지능은 왜 정치적일 수밖에 없는가마크 코켈버그 지음│배...    문화일보
# 47  \n\n강원 양양군 '스마트 관광도시' 선포원스톱 관광 통합 앱 '고고양양' 출시숙...    이데일리
# 48  \n\n김, LG CNS 대표이사 역임박, KT 출신… B2B사업 강점차, 빅데이터...    세계일보
# 49  \n\n  이성진 순천향대 서울병원 교수     닥터 후(Dr.Who) 한국 인구의...    중앙일보

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
results_df.to_csv('/content/drive/MyDrive/Colab Notebooks/results_df.csv')

# %%
results_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/results_df.csv')
results_df.head()
